# %% [markdown]
# Idea:
#
# - Each number is independent.
# - Hence, the total repetitions for each num will likely be equal in the long term.
# - Find the relations between a number to the rest within each draw.
#   - For example, if number 1 is drawn, what are the chances for the other particular number to be drawn based on the previous draws.
#   - So each number will have a dictionary of other 44 numbers while each nested dictionary has two keys: Winning and Supps.
# Later, give more weights to those have higher chances when generating a random ticket number.
#
#
# The process:
# 1. Scan the previous draws and list the dictionary for the number relations.
# 2. Setting some threshold and weights to generate a random ticket
# 3. Each play has 10 tickets
# 4. Check the results: Hypothesis tests

# %%
# Library Imports
import csv
import random
import pandas as pd
from enum import Enum

# %%
# Previous Lotto Records into Lists
wedLotto = satLotto = []
with open('Wednesday Lotto Results - G NETWORK.csv', 'r') as file:
    csv_reader = csv.reader(file, delimiter=',')
    for row in csv_reader:
        wedLotto.append(row)

with open('Saturday Lotto Results - G NETWORK.csv', 'r') as file:
    csv_reader = csv.reader(file, delimiter=',')
    for row in csv_reader:
        satLotto.append(row)
        
wedLotto = wedLotto[1::]
satLotto = satLotto[1::]

# %%
# Go through the previous draws and mark the relations between numbers
wedRelations = {}
satRelations = {}

# list, set, dict are mutable -> pass by reference (if not reassign)
# ig. relationSetter(wedRelations, wedLotto)
def relationSetter(relations, prev_draws) -> dict:
    # String List to Int List
    for draw in prev_draws:
        try:
            drawnTicket = list(map(int, draw[1::]))
        except:
            continue
        for myIndex in range (0, len(drawnTicket)):
            num = drawnTicket[myIndex]
            for itsIndex in range (0, len(drawnTicket)):
            #for num in drawnTicket:
                imSupp = True if myIndex > 5 else False
                itsSupp = True if itsIndex > 5 else False
                numNum = drawnTicket[itsIndex]
                if num != numNum: # Not repeating myself
                    if not num in relations:
                        relations[num] = {'imWinning': {}, 'imSupp':{}}
                    if not numNum in relations[num]['imWinning']:
                        relations[num]['imWinning'][numNum] = {'winning':0, 'itsSupp':0}
                    if not numNum in relations[num]['imSupp']:
                        relations[num]['imSupp'][numNum] = {'winning':0, 'itsSupp':0}
                    # Increment nested dictionary
                    if imSupp:
                        if itsSupp:
                            relations[num]['imSupp'][numNum]['itsSupp'] += 1
                        else:
                            relations[num]['imSupp'][numNum]['winning'] += 1
                    else:
                        if itsSupp:
                            relations[num]['imWinning'][numNum]['itsSupp'] += 1
                        else:
                            relations[num]['imWinning'][numNum]['winning'] += 1

# %%
relationSetter(wedRelations, wedLotto)
relationSetter(satRelations, satLotto)

# %%
wedRelations.get(8)
# Out:
# {'imWinning': {9: {'winning': 13, 'itsSupp': 11},
#   10: {'winning': 19, 'itsSupp': 8},
#   16: {'winning': 19, 'itsSupp': 4},
#   36: {'winning': 17, 'itsSupp': 5},
#   42: {'winning': 20, 'itsSupp': 4},
#   41: {'winning': 16, 'itsSupp': 6},
#   44: {'winning': 17, 'itsSupp': 5},
#   2: {'winning': 13, 'itsSupp': 5},
#   24: {'winning': 9, 'itsSupp': 7},
#   37: {'winning': 15, 'itsSupp': 6},
#   38: {'winning': 14, 'itsSupp': 3},
#   4: {'winning': 14, 'itsSupp': 10},
#   18: {'winning': 18, 'itsSupp': 3},
#   20: {'winning': 12, 'itsSupp': 3},
#   21: {'winning': 11, 'itsSupp': 5},
#   45: {'winning': 19, 'itsSupp': 4},
#   17: {'winning': 8, 'itsSupp': 9},
#   27: {'winning': 23, 'itsSupp': 5},
#   1: {'winning': 14, 'itsSupp': 7},
#   7: {'winning': 20, 'itsSupp': 6},
#   39: {'winning': 16, 'itsSupp': 7},
#   40: {'winning': 17, 'itsSupp': 4},
#   19: {'winning': 10, 'itsSupp': 2},
#   23: {'winning': 22, 'itsSupp': 6},
#   31: {'winning': 19, 'itsSupp': 8},
#   35: {'winning': 16, 'itsSupp': 5},
#   6: {'winning': 17, 'itsSupp': 9},
#   11: {'winning': 13, 'itsSupp': 11},
#   15: {'winning': 19, 'itsSupp': 9},
#   43: {'winning': 15, 'itsSupp': 5},
#   12: {'winning': 19, 'itsSupp': 2},
#   14: {'winning': 14, 'itsSupp': 10},
#   29: {'winning': 20, 'itsSupp': 3},
#   26: {'winning': 14, 'itsSupp': 7},
#   3: {'winning': 13, 'itsSupp': 7},
#   22: {'winning': 16, 'itsSupp': 4},
#   28: {'winning': 17, 'itsSupp': 7},
#   34: {'winning': 15, 'itsSupp': 8},
#   32: {'winning': 13, 'itsSupp': 3},
#   13: {'winning': 19, 'itsSupp': 7},
#   5: {'winning': 12, 'itsSupp': 9},
#   33: {'winning': 18, 'itsSupp': 11},
#   30: {'winning': 11, 'itsSupp': 10},
#   25: {'winning': 14, 'itsSupp': 6}},
#  'imSupp': {9: {'winning': 2, 'itsSupp': 2},
#   10: {'winning': 8, 'itsSupp': 1},
#   16: {'winning': 3, 'itsSupp': 0},
#   36: {'winning': 3, 'itsSupp': 0},
#   42: {'winning': 5, 'itsSupp': 0},
#   41: {'winning': 9, 'itsSupp': 1},
#   44: {'winning': 8, 'itsSupp': 0},
#   2: {'winning': 8, 'itsSupp': 3},
#   24: {'winning': 7, 'itsSupp': 1},
#   37: {'winning': 5, 'itsSupp': 1},
#   38: {'winning': 4, 'itsSupp': 2},
#   4: {'winning': 5, 'itsSupp': 2},
#   18: {'winning': 3, 'itsSupp': 1},
#   20: {'winning': 3, 'itsSupp': 0},
#   21: {'winning': 3, 'itsSupp': 1},
#   45: {'winning': 6, 'itsSupp': 0},
#   17: {'winning': 5, 'itsSupp': 2},
#   27: {'winning': 7, 'itsSupp': 1},
#   1: {'winning': 7, 'itsSupp': 2},
#   7: {'winning': 7, 'itsSupp': 3},
#   39: {'winning': 9, 'itsSupp': 1},
#   40: {'winning': 7, 'itsSupp': 0},
#   19: {'winning': 12, 'itsSupp': 1},
#   23: {'winning': 8, 'itsSupp': 0},
#   31: {'winning': 7, 'itsSupp': 0},
#   35: {'winning': 4, 'itsSupp': 0},
#   6: {'winning': 5, 'itsSupp': 3},
#   11: {'winning': 9, 'itsSupp': 0},
#   15: {'winning': 5, 'itsSupp': 0},
#   43: {'winning': 5, 'itsSupp': 0},
#   12: {'winning': 9, 'itsSupp': 3},
#   14: {'winning': 11, 'itsSupp': 3},
#   29: {'winning': 5, 'itsSupp': 0},
#   26: {'winning': 7, 'itsSupp': 1},
#   3: {'winning': 7, 'itsSupp': 0},
#   22: {'winning': 3, 'itsSupp': 3},
#   28: {'winning': 9, 'itsSupp': 1},
#   34: {'winning': 6, 'itsSupp': 0},
#   32: {'winning': 12, 'itsSupp': 0},
#   13: {'winning': 5, 'itsSupp': 0},
#   5: {'winning': 7, 'itsSupp': 1},
#   33: {'winning': 4, 'itsSupp': 2},
#   30: {'winning': 6, 'itsSupp': 2},
#   25: {'winning': 6, 'itsSupp': 2}}}

# %%
for key, value in wedRelations.items():
    for nested_key, nested_value in value.items():
        print (nested_key)
        print(nested_value)
        break
    break
# Out:
# imWinning
# {9: {'winning': 13, 'itsSupp': 11}, 10: {'winning': 19, 'itsSupp': 8}, 16: {'winning': 19, 'itsSupp': 4}, 36: {'winning': 17, 'itsSupp': 5}, 42: {'winning': 20, 'itsSupp': 4}, 41: {'winning': 16, 'itsSupp': 6}, 44: {'winning': 17, 'itsSupp': 5}, 2: {'winning': 13, 'itsSupp': 5}, 24: {'winning': 9, 'itsSupp': 7}, 37: {'winning': 15, 'itsSupp': 6}, 38: {'winning': 14, 'itsSupp': 3}, 4: {'winning': 14, 'itsSupp': 10}, 18: {'winning': 18, 'itsSupp': 3}, 20: {'winning': 12, 'itsSupp': 3}, 21: {'winning': 11, 'itsSupp': 5}, 45: {'winning': 19, 'itsSupp': 4}, 17: {'winning': 8, 'itsSupp': 9}, 27: {'winning': 23, 'itsSupp': 5}, 1: {'winning': 14, 'itsSupp': 7}, 7: {'winning': 20, 'itsSupp': 6}, 39: {'winning': 16, 'itsSupp': 7}, 40: {'winning': 17, 'itsSupp': 4}, 19: {'winning': 10, 'itsSupp': 2}, 23: {'winning': 22, 'itsSupp': 6}, 31: {'winning': 19, 'itsSupp': 8}, 35: {'winning': 16, 'itsSupp': 5}, 6: {'winning': 17, 'itsSupp': 9}, 11: {'winning': 13, 'itsSupp': 11}, 15: {'winning': 19, 'itsSupp': 9}, 43: {'winning': 15, 'itsSupp': 5}, 12: {'winning': 19, 'itsSupp': 2}, 14: {'winning': 14, 'itsSupp': 10}, 29: {'winning': 20, 'itsSupp': 3}, 26: {'winning': 14, 'itsSupp': 7}, 3: {'winning': 13, 'itsSupp': 7}, 22: {'winning': 16, 'itsSupp': 4}, 28: {'winning': 17, 'itsSupp': 7}, 34: {'winning': 15, 'itsSupp': 8}, 32: {'winning': 13, 'itsSupp': 3}, 13: {'winning': 19, 'itsSupp': 7}, 5: {'winning': 12, 'itsSupp': 9}, 33: {'winning': 18, 'itsSupp': 11}, 30: {'winning': 11, 'itsSupp': 10}, 25: {'winning': 14, 'itsSupp': 6}}

# %%
pd.DataFrame.from_dict(wedRelations.get(8))
# Out:
#                          imWinning                         imSupp
# 9   {'winning': 13, 'itsSupp': 11}   {'winning': 2, 'itsSupp': 2}
# 10   {'winning': 19, 'itsSupp': 8}   {'winning': 8, 'itsSupp': 1}
# 16   {'winning': 19, 'itsSupp': 4}   {'winning': 3, 'itsSupp': 0}
# 36   {'winning': 17, 'itsSupp': 5}   {'winning': 3, 'itsSupp': 0}
# 42   {'winning': 20, 'itsSupp': 4}   {'winning': 5, 'itsSupp': 0}
# 41   {'winning': 16, 'itsSupp': 6}   {'winning': 9, 'itsSupp': 1}
# 44   {'winning': 17, 'itsSupp': 5}   {'winning': 8, 'itsSupp': 0}
# 2    {'winning': 13, 'itsSupp': 5}   {'winning': 8, 'itsSupp': 3}
# 24    {'winning': 9, 'itsSupp': 7}   {'winning': 7, 'itsSupp': 1}
# 37   {'winning': 15, 'itsSupp': 6}   {'winning': 5, 'itsSupp': 1}
# 38   {'winning': 14, 'itsSupp': 3}   {'winning': 4, 'itsSupp': 2}
# 4   {'winning': 14, 'itsSupp': 10}   {'winning': 5, 'itsSupp': 2}
# 18   {'winning': 18, 'itsSupp': 3}   {'winning': 3, 'itsSupp': 1}
# 20   {'winning': 12, 'itsSupp': 3}   {'winning': 3, 'itsSupp': 0}
# 21   {'winning': 11, 'itsSupp': 5}   {'winning': 3, 'itsSupp': 1}
# 45   {'winning': 19, 'itsSupp': 4}   {'winning': 6, 'itsSupp': 0}
# 17    {'winning': 8, 'itsSupp': 9}   {'winning': 5, 'itsSupp': 2}
# 27   {'winning': 23, 'itsSupp': 5}   {'winning': 7, 'itsSupp': 1}
# 1    {'winning': 14, 'itsSupp': 7}   {'winning': 7, 'itsSupp': 2}
# 7    {'winning': 20, 'itsSupp': 6}   {'winning': 7, 'itsSupp': 3}
# 39   {'winning': 16, 'itsSupp': 7}   {'winning': 9, 'itsSupp': 1}
# 40   {'winning': 17, 'itsSupp': 4}   {'winning': 7, 'itsSupp': 0}
# 19   {'winning': 10, 'itsSupp': 2}  {'winning': 12, 'itsSupp': 1}
# 23   {'winning': 22, 'itsSupp': 6}   {'winning': 8, 'itsSupp': 0}
# 31   {'winning': 19, 'itsSupp': 8}   {'winning': 7, 'itsSupp': 0}
# 35   {'winning': 16, 'itsSupp': 5}   {'winning': 4, 'itsSupp': 0}
# 6    {'winning': 17, 'itsSupp': 9}   {'winning': 5, 'itsSupp': 3}
# 11  {'winning': 13, 'itsSupp': 11}   {'winning': 9, 'itsSupp': 0}
# 15   {'winning': 19, 'itsSupp': 9}   {'winning': 5, 'itsSupp': 0}
# 43   {'winning': 15, 'itsSupp': 5}   {'winning': 5, 'itsSupp': 0}
# 12   {'winning': 19, 'itsSupp': 2}   {'winning': 9, 'itsSupp': 3}
# 14  {'winning': 14, 'itsSupp': 10}  {'winning': 11, 'itsSupp': 3}
# 29   {'winning': 20, 'itsSupp': 3}   {'winning': 5, 'itsSupp': 0}
# 26   {'winning': 14, 'itsSupp': 7}   {'winning': 7, 'itsSupp': 1}
# 3    {'winning': 13, 'itsSupp': 7}   {'winning': 7, 'itsSupp': 0}
# 22   {'winning': 16, 'itsSupp': 4}   {'winning': 3, 'itsSupp': 3}
# 28   {'winning': 17, 'itsSupp': 7}   {'winning': 9, 'itsSupp': 1}
# 34   {'winning': 15, 'itsSupp': 8}   {'winning': 6, 'itsSupp': 0}
# 32   {'winning': 13, 'itsSupp': 3}  {'winning': 12, 'itsSupp': 0}
# 13   {'winning': 19, 'itsSupp': 7}   {'winning': 5, 'itsSupp': 0}
# 5    {'winning': 12, 'itsSupp': 9}   {'winning': 7, 'itsSupp': 1}
# 33  {'winning': 18, 'itsSupp': 11}   {'winning': 4, 'itsSupp': 2}
# 30  {'winning': 11, 'itsSupp': 10}   {'winning': 6, 'itsSupp': 2}
# 25   {'winning': 14, 'itsSupp': 6}   {'winning': 6, 'itsSupp': 2}

# %%
# enum for diff lotto
class Lotto(Enum):
    WED = 1
    SAT = 2
    
class Division(Enum):
    first = "First"
    second = "Second"
    third = "Third"
    fourth = "Fourth"
    fifth = "Fifth"
    sixth = "Sixth"
    failed = "Failed"
    

def ticketMarker(tickets, lotto, drawnNums) -> dict:
    winning_match = 0
    supp_match = 0
    # String List to Int List
    drawnTicket = list(map(int, wedLotto[1][1::]))
    results = {'First':0, 'Second':0, 'Third':0, 'Fourth':0,
              'Fifth':0, 'Sixth':0, 'Failed':0}
    for ticket in tickets:
        print(ticket)
        results[divisionCalc(ticket, lotto, drawnTicket)] += 1
    
    return results

    

def divisionCalc(ticket, lotto, drawnTicket) -> str:
    winning_match = 0
    supp_match = 0
    
    # To compare two lists -> need two indices
    drawnIndex = 0
    ticketIndex = 0
    while ticketIndex < len(ticket) and drawnIndex < len(ticket):
        ticketNum = ticket[ticketIndex]
        drawnNum = drawnTicket[drawnIndex]
        if ticketNum < drawnNum:
            # missed the drawnNum - drawnNum holds
            ticketIndex += 1
            continue 
        elif ticketNum == drawnNum:
            if index > 5: 
                supp_match += 1
            else:
                winnings_match += 1
            # Hit the drawnNum; Move to the next one
            drawnIndex += 1; ticketIndex += 1;
        else:
            # smaller than drawnNums - ticketNum holds
            drawnIndex += 1
    
    # Division Check
    # Rules - Common
    # 1. 6 winnings 2. 5 winnings + 1 supp 3. 5 winnings
    # 4. 4 winnings 
    if winning_match == 6:
        return Division.first.value
    elif winning_match == 5:
        if supp_match == 1:
            return Division.second.value
        else:
            return Division.third.value
    elif winning_match == 4:
        return  Division.fourth.value
    
    # Rules - Wed
    # 5. 3 winnings + 2 supp 6. total 3 (winning 1 + 2, 2 + 1)
    # Rules - Sat
    # 5. 3 winnings + 1 supp 6. 3 winnings
    if lotto == Lotto.WED:
        if winning_match == 3 and supp_match == 2:
            return Division.fifth.value
        else:
            if winning_match + supp_match == 3:
                return Division.sixth.value
            else:
                return Division.failed.value
    else:
        if winning_match == 3 and supp_match == 2:
            return Division.fifth.value
        else:
            if winning_match == 3:
                return Division.sixth.value
            else:
                return Division.failed.value

# %%
tenTickets = []
for index in range(0,10):
    tenTickets.append(ticketGenerator())


ticketRow = wedLotto[0]
result = [ticketMarker(tenTickets, Lotto.SAT, ticketRow)]
result2 = ticketMarker(tenTickets, Lotto.SAT, ticketRow)
result.append(result2)

# %%
#result = sorted(result, key = lambda k: k['First'])
result
