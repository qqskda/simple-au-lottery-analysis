# %% [markdown]
# Automatic Update/Collect Draws
#
# 1. Request 50 Draws each time of request (max_permitted)
# 2. Check the response
# 3. Save it in json()
# 4. Parsing and store the data
# 5. Check the Update Interval (date?) -> Request the new draw at the right time.
# 6. ...
#
# ### Why drawrange over daterange?
# drawrange allows upto 50 and 24 at once while daterange allows 90 days.
#
# Since the lottery is weekly-drawn, daterange allows to get maximum 12 draws per request.
#
# ### About MonWedLotto?
# MonWedLotto use the same machine, and draws twice weekly; mon and wed.
#
# Since the purpose of this project is to analyze the tendency of a "machine" I did not separated two draws.
#
# Even draw Nums are Monday
#
# Odd  draw Nums are Wed
#
# ### Why 2012 Jan?
# 1. API supports draws starting from different date.
# 2. Apply fairly "recent" tendencies.

# %%
import requests
import pandas as pd
from enum import Enum
import time
from datetime import date
from requests.exceptions import Timeout

# %%
# Classes - Different Lottery has diff rules

class Lotto:
    def __init__(self, game_name, draw_num):
        self.game_name = game_name
        self.draw_num = draw_num
        self.interval = 7
        self.last_draw = 0
        
    def update_last_drawn(self, string_date: str):
        self.last_draw = pd.to_datetime(string_date)
        print("Updated the Lotto Last Drawn Date to: ", self.last_draw)

    def is_time_to_crawl(self):
        return pd.to_datetime(date.today()) >= self.last_draw + pd.DateOffset(7)

# %%
# Basic Parameter Setup
# Two Lotto shares the same data.api url as following
url = 'https://data.api.thelott.com/sales/vmax/web/data/lotto/results/search/drawrange'

# Payload Setup 
payload_template = {'MinDrawNo': None, 'MaxDrawNo': None, 'Product': None, 'CompanyFilter': ["NSWLotteries"]}

# %%
# Create request payload in json format (dict)
# Request 50 draws at one time (api request limit)
def create_payload(game: Lotto) -> dict:
    payload_template = {'MinDrawNo': None, 'MaxDrawNo': None, 'Product': None, 'CompanyFilter': ["NSWLotteries"]}
    ret_payload = payload_template.copy()
    ret_payload['MinDrawNo'] = int(game.draw_num)
    ret_payload['MaxDrawNo'] = int(game.draw_num + 49)
    ret_payload['Product'] = game.game_name
    return ret_payload

# %%
# request Setup
wed_data = pd.DataFrame()
sat_data = pd.DataFrame()

def do_request(url, payload):
    try:
        print(payload)
        r = requests.post(url, json = payload, timeout = (2,5))
    except Timeout:
        print('Request', payload['MinDrawNo'], 'TimeOut')
        return
    else:
        if r.status_code == 200:
            print('Request', payload['MinDrawNo'], 'Success')
        else:
            print('Request ', payload['MinDrawNo'], 'Failed - ', r.status_code)
            return
    
    response = r.json()
    
    if response['ErrorInfo'] != None:
        print("Error - May have issues with parameter of payload")
        print(payload)
        return
    
    return response

def interpret_response(data, response):
    draws = pd.DataFrame.from_dict(response['Draws'])
    try:
        data = pd.concat([draws, data])
    except:
        print("parse_response: Data Append Failed")
        return
    else:
        print("parse_response: Data Append Success")
        return data, draws['DrawNumber'][0]

# %%
# Website has no previous draws for MonWedLotto
startNo_monWed = 3108 # 2012 Jan 30
startNo_sat = 3185 # 2012 Jan 28
wed_game = Lotto('MonWedLotto', startNo_monWed)
sat_game = Lotto('TattsLotto', startNo_sat)

# %%
# Script Function

def crawl_all(wed_data, wed_game: Lotto, sat_data, sat_game: Lotto):
    recent_draws = 0
    wed_crawl_done = False
    while not wed_crawl_done:
        wed_payload = create_payload(wed_game)
        response = do_request(url, wed_payload)
        if len(response['Draws']) == 0 or response == None:
            wed_crawl_done = True
        else:
            wed_data, recent_draws = interpret_response(wed_data, response)
            print("MonWed Draws from: ", wed_game.draw_num, "to", recent_draws)
            wed_game.draw_num = recent_draws + 1
            time.sleep(2)
            
    print("monWed Draws Completed upto", recent_draws)
    print("Now Moving on to Sat Draws")
    
    sat_crawl_done = False
    while not sat_crawl_done:
        sat_payload = create_payload(sat_game)
        response = do_request(url, sat_payload)
        if  len(response['Draws']) == 0 or response == None:
            sat_crawl_done = True
        else:
            sat_data, recent_draws = interpret_response(sat_data, response)
            print("Sat Draws from: ", sat_game.draw_num, "to", recent_draws)
            sat_game.draw_num = recent_draws + 1
            time.sleep(2)            
    
    print("sat Draws Completed upto", recent_draws)
    print("Now Wrapping up crawlling")
    
    if len(wed_data) != 0:
        date = wed_data['DrawDate'].head(1).values[0]
        wed_game.update_last_drawn(date)
    
    if len(sat_data) != 0:
        date = sat_data['DrawDate'].head(1).values[0]
        sat_game.update_last_drawn(date)
    
    return wed_data, wed_game, sat_data, sat_game

# %%
wed_data, wed_game, sat_data, sat_game = crawl_all(wed_data, wed_game, sat_data, sat_game)
# Out:
# {'MinDrawNo': 3108, 'MaxDrawNo': 3157, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3108 Success
# parse_response: Data Append Success
# MonWed Draws from:  3108 to 3157
# {'MinDrawNo': 3158, 'MaxDrawNo': 3207, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3158 Success
# parse_response: Data Append Success
# MonWed Draws from:  3158 to 3207
# {'MinDrawNo': 3208, 'MaxDrawNo': 3257, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3208 Success
# parse_response: Data Append Success
# MonWed Draws from:  3208 to 3257
# {'MinDrawNo': 3258, 'MaxDrawNo': 3307, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3258 Success
# parse_response: Data Append Success
# MonWed Draws from:  3258 to 3307
# {'MinDrawNo': 3308, 'MaxDrawNo': 3357, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3308 Success
# parse_response: Data Append Success
# MonWed Draws from:  3308 to 3357
# {'MinDrawNo': 3358, 'MaxDrawNo': 3407, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3358 Success
# parse_response: Data Append Success
# MonWed Draws from:  3358 to 3407
# {'MinDrawNo': 3408, 'MaxDrawNo': 3457, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3408 Success
# parse_response: Data Append Success
# MonWed Draws from:  3408 to 3457
# {'MinDrawNo': 3458, 'MaxDrawNo': 3507, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3458 Success
# parse_response: Data Append Success
# MonWed Draws from:  3458 to 3507
# {'MinDrawNo': 3508, 'MaxDrawNo': 3557, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3508 Success
# parse_response: Data Append Success
# MonWed Draws from:  3508 to 3557
# {'MinDrawNo': 3558, 'MaxDrawNo': 3607, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3558 Success
# parse_response: Data Append Success
# MonWed Draws from:  3558 to 3607
# {'MinDrawNo': 3608, 'MaxDrawNo': 3657, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3608 Success
# parse_response: Data Append Success
# MonWed Draws from:  3608 to 3657
# {'MinDrawNo': 3658, 'MaxDrawNo': 3707, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3658 Success
# parse_response: Data Append Success
# MonWed Draws from:  3658 to 3707
# {'MinDrawNo': 3708, 'MaxDrawNo': 3757, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3708 Success
# parse_response: Data Append Success
# MonWed Draws from:  3708 to 3757
# {'MinDrawNo': 3758, 'MaxDrawNo': 3807, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3758 Success
# parse_response: Data Append Success
# MonWed Draws from:  3758 to 3807
# {'MinDrawNo': 3808, 'MaxDrawNo': 3857, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3808 Success
# parse_response: Data Append Success
# MonWed Draws from:  3808 to 3857
# {'MinDrawNo': 3858, 'MaxDrawNo': 3907, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3858 Success
# parse_response: Data Append Success
# MonWed Draws from:  3858 to 3907
# {'MinDrawNo': 3908, 'MaxDrawNo': 3957, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3908 Success
# parse_response: Data Append Success
# MonWed Draws from:  3908 to 3957
# {'MinDrawNo': 3958, 'MaxDrawNo': 4007, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3958 Success
# parse_response: Data Append Success
# MonWed Draws from:  3958 to 4007
# {'MinDrawNo': 4008, 'MaxDrawNo': 4057, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 4008 Success
# parse_response: Data Append Success
# MonWed Draws from:  4008 to 4057
# {'MinDrawNo': 4058, 'MaxDrawNo': 4107, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 4058 Success
# parse_response: Data Append Success
# MonWed Draws from:  4058 to 4061
# {'MinDrawNo': 4062, 'MaxDrawNo': 4111, 'Product': 'MonWedLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 4062 Success
# monWed Draws Completed upto 4061
# Now Moving on to Sat Draws
# {'MinDrawNo': 3185, 'MaxDrawNo': 3234, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3185 Success
# parse_response: Data Append Success
# Sat Draws from:  3185 to 3233
# {'MinDrawNo': 3234, 'MaxDrawNo': 3283, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3234 Success
# parse_response: Data Append Success
# Sat Draws from:  3234 to 3283
# {'MinDrawNo': 3284, 'MaxDrawNo': 3333, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3284 Success
# parse_response: Data Append Success
# Sat Draws from:  3284 to 3333
# {'MinDrawNo': 3334, 'MaxDrawNo': 3383, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3334 Success
# parse_response: Data Append Success
# Sat Draws from:  3334 to 3383
# {'MinDrawNo': 3384, 'MaxDrawNo': 3433, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3384 Success
# parse_response: Data Append Success
# Sat Draws from:  3384 to 3433
# {'MinDrawNo': 3434, 'MaxDrawNo': 3483, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3434 Success
# parse_response: Data Append Success
# Sat Draws from:  3434 to 3483
# {'MinDrawNo': 3484, 'MaxDrawNo': 3533, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3484 Success
# parse_response: Data Append Success
# Sat Draws from:  3484 to 3533
# {'MinDrawNo': 3534, 'MaxDrawNo': 3583, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3534 Success
# parse_response: Data Append Success
# Sat Draws from:  3534 to 3583
# {'MinDrawNo': 3584, 'MaxDrawNo': 3633, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3584 Success
# parse_response: Data Append Success
# Sat Draws from:  3584 to 3633
# {'MinDrawNo': 3634, 'MaxDrawNo': 3683, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3634 Success
# parse_response: Data Append Success
# Sat Draws from:  3634 to 3683
# {'MinDrawNo': 3684, 'MaxDrawNo': 3733, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3684 Success
# parse_response: Data Append Success
# Sat Draws from:  3684 to 3733
# {'MinDrawNo': 3734, 'MaxDrawNo': 3783, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3734 Success
# parse_response: Data Append Success
# Sat Draws from:  3734 to 3783
# {'MinDrawNo': 3784, 'MaxDrawNo': 3833, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3784 Success
# parse_response: Data Append Success
# Sat Draws from:  3784 to 3833
# {'MinDrawNo': 3834, 'MaxDrawNo': 3883, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3834 Success
# parse_response: Data Append Success
# Sat Draws from:  3834 to 3883
# {'MinDrawNo': 3884, 'MaxDrawNo': 3933, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3884 Success
# parse_response: Data Append Success
# Sat Draws from:  3884 to 3933
# {'MinDrawNo': 3934, 'MaxDrawNo': 3983, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3934 Success
# parse_response: Data Append Success
# Sat Draws from:  3934 to 3983
# {'MinDrawNo': 3984, 'MaxDrawNo': 4033, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 3984 Success
# parse_response: Data Append Success
# Sat Draws from:  3984 to 4033
# {'MinDrawNo': 4034, 'MaxDrawNo': 4083, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 4034 Success
# parse_response: Data Append Success
# Sat Draws from:  4034 to 4083
# {'MinDrawNo': 4084, 'MaxDrawNo': 4133, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 4084 Success
# parse_response: Data Append Success
# Sat Draws from:  4084 to 4133
# {'MinDrawNo': 4134, 'MaxDrawNo': 4183, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 4134 Success
# parse_response: Data Append Success
# Sat Draws from:  4134 to 4137
# {'MinDrawNo': 4138, 'MaxDrawNo': 4187, 'Product': 'TattsLotto', 'CompanyFilter': ['NSWLotteries']}
# Request 4138 Success
# sat Draws Completed upto 4137
# Now Wrapping up crawlling
# Updated the Lotto Last Drawn Date to:  2021-03-17 00:00:00
# Updated the Lotto Last Drawn Date to:  2021-03-13 00:00:00

# %%
# Write to csv
wed_data.to_csv('Crawled_MonWed.csv', encoding='utf-8', index=False)
sat_data.to_csv('Crawled_Sat.csv', encoding='utf-8', index=False)
